# %%
# %matplotlib inline
import pandas as pd
import csv
import numpy as np
import time 
import datetime
import matplotlib.pyplot as plt
import pylab as pl

# %%
df = pd.DataFrame.from_csv('D:/Nanohub/results/datetime_plot_2015.csv', sep ='\t', encoding = 'UTF-8', header = None)
df.columns = ['date','count']

# %%
df.plot(x ='date', y='count') #figsize = (60,30)

# %%
df_timeline
# Out:
#        date_col     ip
#                  count
# 0    2015-01-01    211
# 1    2015-01-02    224
# 2    2015-01-03    160
# 3    2015-01-04    210
# 4    2015-01-05    585
# 5    2015-01-06    461
# 6    2015-01-07   1545
# 7    2015-01-08    652
# 8    2015-01-09    668
# 9    2015-01-10    198
# 10   2015-01-11    575
# 11   2015-01-12    786
# 12   2015-01-13    724
# 13   2015-01-14    749
# 14   2015-01-15    703
# 15   2015-01-16    928
# 16   2015-01-17    478
# 17   2015-01-18    360
# 18   2015-01-19    979
# 19   2015-01-20   1015
# 20   2015-01-21    684
# 21   2015-01-22    601
# 22   2015-01-23    573
# 23   2015-01-24    194
# 24   2015-01-25    210
# 25   2015-01-26    805
# 26   2015-01-27   1167
# 27   2015-01-29    873
# 28   2015-01-30   1640
# 29   2015-01-31    191
# ..          ...    ...
# 284  2015-10-13    680
# 285  2015-10-14   1642
# 286  2015-10-15    889
# 287  2015-10-16    616
# 288  2015-10-17    264
# 289  2015-10-18    311
# 290  2015-10-19    752
# ...

# %%
df_timeline['date_col']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\mugdh\Anaconda3\envs\trisket\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'date_col'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-838266cc0e07> in <module>()
# ...
