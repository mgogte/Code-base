# %%
import pandas as pd
import csv
import numpy as np
import time 
from math import radians, cos, sin, asin, sqrt
import re, math
import matplotlib.pyplot as plt
from haversine import haversine
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import jaccard_similarity_score
# %matplotlib inline
np.set_printoptions(threshold=np.nan)
import warnings
warnings.filterwarnings('ignore')

# %%
df_2015 = pd.DataFrame.from_csv('D:/Nanohub/TribeFlow/TF_location_2015.csv', sep ='\t', encoding = 'UTF-8', header = None)
df_2015.columns = ['ip','resource id','datetime','latitude','longitude']

uniq_ip_2015 = df_2015['ip'].unique()
uniq_res_2015 = df_2015['resource id'].unique()

# %%
counts = df_2015.groupby('resource id')
counts[['resource id']].transform(sum).sort('resource id')
# Out:
#            resource id
# 0
# 393415997           33
# 406538744           43
# 428857449           52
# 559312803           70
# 438730190          108
# 440849817          108
# 559784302          112
# 560219848          146
# 544327972          146
# 434682342          166
# 556241618          166
# 434948897          216
# 454149951          216
# 451534905          216
# 423657378          256
# 447757140          271
# 558877851          296
# 407959383          296
# 558877851          296
# 549254563          303
# 444562794          305
# 445872611          316
# 445871913          317
# 422334494          334
# 547796195          334
# 440753201          335
# 445151110          336
# 435638944          336
# 418880353          336
# 451534778          336
# ...                ...
# 455876712      4812276
# 455876712      4812276
# 454909067      4812276
# 454909067      4812276
# 454770945      4812276
# 454770945      4812276
# 454202151      4812276
# 454202151      4812276
# 451154926      4812276
# 561557992      4812276
# 561557992      4812276
# 452907755      4812276
# 552892477      4812276
# 426499986      4812276
# 426499986      4812276
# 454507568      4812276
# 454507568      4812276
# 554973192      4812276
# 554973192      4812276
# 555095137      4812276
# 449491916      4812276
# 409237762      4812276
# 409237762      4812276
# 555363126      4812276
# 555363126      4812276
# 550053315      4812276
# 550053315      4812276
# 452907755      4812276
# 449491916      4812276
# 406457582      4812276
#
# [30917 rows x 1 columns]

# %%
jacc_sims = np.zeros((len(uniq_res_2015),len(uniq_ip_2015)))
for i in range(len(uniq_ip_2015)):
    curr =  df_2015[df_2015['ip'] == uniq_ip_2015[i]]
    for j in range(len(uniq_res_2015)):
        if( uniq_res_2015[j] in curr['resource id'].values):
            jacc_sims[j][i] = 1

# %%
jacc_sims.shape
jacc_sims[2001]
uniq_res_2015[2001] #resource id 10
uniq_res_2015[1994] #resource id 11
# Out:
# 11

# %%
#jaccard's sim
j = 2001

simres = []
for i in range(len(jacc_sims)):
    jacc_sim = jaccard_similarity_score(jacc_sims[j], jacc_sims[i])
    simres.append(jacc_sims[i])
print(simres)

# %%
j = 1994

simres = []
cossim = cosine_similarity(sims[j], sims).flatten()
sim_ress = []
for i in range(len(cossim)):
    if(cossim[i] > 0.5 and cossim[i] < 1):
        sim_ress.append(uniq_res_2015[i])
print(uniq_res_2015[j],sim_ress)
# Out:
# 11 [42, 13, 31, 26, 21, 15, 19, 16, 20, 18, 17, 14, 10, 51, 57, 59, 60, 62]

# %%
j = 1994

simres = []
cossim = cosine_similarity(sims[j], sims).flatten()
sim_ress = []
for i in range(len(cossim)):
    if(cossim[i] > 0.5 and cossim[i] < 1):
        sim_ress.append(uniq_res_2015[i])
print(uniq_res_2015[j],sim_ress)
